# %% [markdown]
# Finding duplicated images
# ==
#
# - Last updated: 20181126
# - Claire

# %%
# https://www.kaggle.com/c/human-protein-atlas-image-classification/discussion/72534
# https://github.com/MotorCityCobra/face_ripper_9000/blob/master/duplicate_image_finder.ipynb

# %%
from PIL import Image
import six
import imagehash
import os, os.path
from shutil import copyfile

# %%
TRAIN_PATH = os.getenv("TRAIN_PATH", "../../../data/official/train/")
TEST_PATH = os.getenv("TEST_PATH", "../../../data/fficial/test/")

# %%
gpath = TRAIN_PATH

# %%
green = [i for i in (os.listdir(gpath)) if len(i) == 46]

# %%
len(green)
# Out:
# 31072

# %%
duplicates = '../../../data/official/dups'

# %% [markdown]
# ahash, phash, dhash

# %%
images = {}
for img in (green):
    hash = imagehash.dhash(Image.open(f'{gpath}{img}'))
    images[hash] = images.get(hash, []) + [img]

# %%
images
# Out:
# {array([[ True, False,  True,  True, False, False, False,  True],
#         [ True, False,  True, False,  True,  True, False,  True],
#         [ True,  True,  True, False,  True,  True, False, False],
#         [False,  True, False,  True,  True, False, False,  True],
#         [False,  True, False,  True, False, False,  True, False],
#         [ True, False,  True,  True, False,  True,  True,  True],
#         [ True, False,  True, False, False,  True,  True, False],
#         [False,  True, False,  True,  True, False, False, False]]): ['dc280322-bbbc-11e8-b2ba-ac1f6b6435d0_green.png'],
#  array([[False,  True, False, False,  True,  True, False, False],
#         [False,  True, False, False,  True,  True, False, False],
#         [False, False, False, False, False,  True,  True,  True],
#         [ True,  True, False, False, False, False,  True, False],
#         [ True, False, False,  True, False, False,  True,  True],
# ...

# %%
copies = []
for k, img_list in six.iteritems(images):
    if len(img_list) > 1:
        copies.append(img_list)

# %%
counter = 1
for i in copies:
    os.makedirs(f'{duplicates}{counter}', exist_ok=True)
    counter += 1

# %%
counter = 1
for i in copies:
    for xx in i:
        copyfile(f'{gpath}{xx}', f'{duplicates}{counter}/{xx}')
    counter += 1

# %%
duplicates
# Out:
# '../../../data/official/dups'

# %% [markdown]
# ---
# ## ideas
# - check similar images between different channels as well, they can be immediate hints for simple localization
# - check for outlines: for many cases, molecules may either fill a compartment, or localize on the membrane surfaces
# - some marker channels got no signals, drop them from training and develop code to drop when encountered
# - check out ImageJ scripts

# %%
counter
# Out:
# 78

# %%
copies
# Out:
# [['d52a06a2-bbca-11e8-b2bc-ac1f6b6435d0_green.png',
#   '79161d98-bb9c-11e8-b2b9-ac1f6b6435d0_green.png'],
#  ['679ee654-bbaf-11e8-b2ba-ac1f6b6435d0_green.png',
#   '730d86b0-bbc5-11e8-b2bc-ac1f6b6435d0_green.png'],
#  ['74b52b52-bbbc-11e8-b2ba-ac1f6b6435d0_green.png',
#   '559f7ce0-bbb2-11e8-b2ba-ac1f6b6435d0_green.png'],
#  ['11363eec-bbb5-11e8-b2ba-ac1f6b6435d0_green.png',
#   '940dbd80-bbca-11e8-b2bc-ac1f6b6435d0_green.png'],
#  ['43f2a8a6-bbbb-11e8-b2ba-ac1f6b6435d0_green.png',
#   '6a5ca738-bba4-11e8-b2b9-ac1f6b6435d0_green.png'],
#  ['4af12632-bbac-11e8-b2ba-ac1f6b6435d0_green.png',
#   '8c388d9e-bbb4-11e8-b2ba-ac1f6b6435d0_green.png'],
#  ['88c3e902-bbc7-11e8-b2bc-ac1f6b6435d0_green.png',
#   'efa50dd2-bb9e-11e8-b2b9-ac1f6b6435d0_green.png'],
#  ['eeecda56-bbc0-11e8-b2bb-ac1f6b6435d0_green.png',
#   '050a106a-bbc1-11e8-b2bb-ac1f6b6435d0_green.png'],
#  ['80ea0dc4-bbb3-11e8-b2ba-ac1f6b6435d0_green.png',
#   'ad2eff22-bba7-11e8-b2ba-ac1f6b6435d0_green.png'],
# ...

# %% [raw]
# phash output:
# [['7a092afe-bba3-11e8-b2b9-ac1f6b6435d0_green.png',
#   '2f4396cc-bba2-11e8-b2b9-ac1f6b6435d0_green.png'],
#  