# %%
import pandas as pd

# %%
df = pd.read_csv('../../../data/proteinatlas.tsv', delimiter='\t')

# %%
df.shape
# Out:
# (19613, 22)

# %%
df.head()
# Out:
#        Gene                          Gene synonym          Ensembl  \
# 0    TSPAN6                 T245, TM4SF6, TSPAN-6  ENSG00000000003
# 1      TNMD  BRICD4, ChM1L, myodulin, TEM, tendin  ENSG00000000005
# 2      DPM1                           CDGIE, MPDS  ENSG00000000419
# 3     SCYL3                         PACE-1, PACE1  ENSG00000000457
# 4  C1orf112                              FLJ10706  ENSG00000000460
#
#                                     Gene description Chromosome  \
# 0                                      Tetraspanin 6          X
# 1                                        Tenomodulin          X
# 2  Dolichyl-phosphate mannosyltransferase subunit...         20
# 3                           SCY1 like pseudokinase 3          1
# 4                Chromosome 1 open reading frame 112          1
#
#               Position                                      Protein class  \
# 0  100627109-100639991  Predicted intracellular proteins, Predicted me...
# ...
